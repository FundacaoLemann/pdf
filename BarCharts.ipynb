# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./data_sample.bar_chart.csv', delimiter='|', index_col=[0], header=0)

# %%
df
# Out:
#                  USUARIOS
# X_LABEL
# aparecida              40
# camelialoff             8
# helenaguerra           68
# sandovalazevedo        12

# %% [markdown]
# # Generate the plot

# %%
params = {
    'kind': 'bar',
    'ylim': (0, 100),
    'legend': False,
    'figsize': (14, 7),
    'grid': True,
    'color': "#339966",
    'rot': 0
}

# %%
# generate the plot
plot = df.plot(**params)

# annotate the values above the bars
for idx, label in enumerate(list(df.index)): 
    for acc in df.columns:
        value = np.round(df.ix[idx][acc],decimals=2)
        plot.annotate(value, (idx, value), xytext=(0, 15), textcoords='offset points')

# set the labels
plot.set_ylabel('% USUARIOS')
plot.set_xlabel('X LABEL')

# export chart
fig = plot.get_figure()
fig.savefig("output.png")

# %%
from weasyprint import HTML
HTML('ab.html').write_pdf('/tmp/weekly_report.pdf')
# Out:
# Ignored `-webkit-text-size-adjust: 100%` at 5:108, unknown property.
# Ignored `-ms-text-size-adjust: 100%` at 5:138, unknown property.
# Ignored `-webkit-box-sizing: content-box` at 5:846, unknown property.
# Ignored `-moz-box-sizing: content-box` at 5:877, unknown property.
# Ignored `-webkit-appearance: button` at 5:1210, unknown property.
# Ignored `cursor: pointer` at 5:1236, the property does not apply for the print media.
# Ignored `cursor: default` at 5:1289, the property does not apply for the print media.
# Invalid or unsupported selector 'button::-moz-focus-inner,input::-moz-focus-inner', Unknown pseudo-element: -moz-focus-inner
# Ignored `-webkit-box-sizing: border-box` at 5:1436, unknown property.
# Ignored `-moz-box-sizing: border-box` at 5:1466, unknown property.
# Invalid or unsupported selector 'input[type=number]::-webkit-inner-spin-button,input[type=number]::-webkit-outer-spin-button', Unknown pseudo-element: -webkit-inner-spin-button
# Ignored `-webkit-box-sizing: content-box` at 5:1648, unknown property.
# Ignored `-moz-box-sizing: content-box` at 5:1679, unknown property.
# Ignored `-webkit-appearance: textfield` at 5:1730, unknown property.
# Ignored `-webkit-appearance: none` at 5:1854, unknown property.
# Ignored `text-shadow: none` at 5:2225, unknown property.
# Ignored `-webkit-box-shadow: none` at 5:2277, unknown property.
# Ignored `box-shadow: none` at 5:2311, unknown property.
# Ignored `-webkit-font-smoothing: antialiased` at 5:3619, unknown property.
# Ignored `-moz-osx-font-smoothing: grayscale` at 5:3654, unknown property.
# Ignored `-webkit-box-sizing: border-box` at 5:15123, unknown property.
# Ignored `-moz-box-sizing: border-box` at 5:15153, unknown property.
# Ignored `-webkit-box-sizing: border-box` at 5:15217, unknown property.
# Ignored `-moz-box-sizing: border-box` at 5:15247, unknown property.
# Ignored `-webkit-tap-highlight-color: rgba(0,0,0,0)` at 5:15316, unknown property.
# Ignored `outline: 5px auto -webkit-focus-ring-color` at 5:15678, invalid value.
# Ignored `outline-offset: -2px` at 5:15720, unknown property.
# Ignored `-webkit-transition: all .2s ease-in-out` at 5:16116, unknown property.
# Ignored `-o-transition: all .2s ease-in-out` at 5:16155, unknown property.
# Ignored `transition: all .2s ease-in-out` at 5:16189, unknown property.
# Ignored `cursor: pointer` at 5:16577, the property does not apply for the print media.
# Ignored `cursor: help` at 5:19577, the property does not apply for the print media.
# Ignored `-webkit-box-shadow: inset 0 -1px 0 rgba(0,0,0,.25)` at 5:20959, unknown property.
# Ignored `box-shadow: inset 0 -1px 0 rgba(0,0,0,.25)` at 5:21009, unknown property.
# Ignored `-webkit-box-shadow: none` at 5:21100, unknown property.
# Ignored `box-shadow: none` at 5:21124, unknown property.
# Ignored `word-break: break-all` at 5:21237, unknown property.
# Ignored `overflow-y: scroll` at 5:21494, unknown property.
# Ignored `overflow-x: auto` at 5:33812, unknown property.
# Ignored `-webkit-box-sizing: border-box` at 5:35577, unknown property.
# Ignored `-moz-box-sizing: border-box` at 5:35607, unknown property.
# Ignored `margin-top: 1px\9` at 5:35710, invalid value.
# Ignored `outline: 5px auto -webkit-focus-ring-color` at 5:35936, invalid value.
# Ignored `outline-offset: -2px` at 5:35978, unknown property.
# Ignored `-webkit-box-shadow: inset 0 1px 1px rgba(0,0,0,.075)` at 5:36285, unknown property.
# Ignored `box-shadow: inset 0 1px 1px rgba(0,0,0,.075)` at 5:36337, unknown property.
# Ignored `-webkit-transition: border-color ease-in-out .15s,-webkit-box-shadow ease-in-out .15s` at 5:36381, unknown property.
# Ignored `-o-transition: border-color ease-in-out .15s,box-shadow ease-in-out .15s` at 5:36466, unknown property.
# Ignored `transition: border-color ease-in-out .15s,box-shadow ease-in-out .15s` at 5:36538, unknown property.
# Ignored `-webkit-box-shadow: inset 0 1px 1px rgba(0,0,0,.075),0 0 8px rgba(102,175,233,.6)` at 5:36658, unknown property.
# Ignored `box-shadow: inset 0 1px 1px rgba(0,0,0,.075),0 0 8px rgba(102,175,233,.6)` at 5:36739, unknown property.
# Invalid or unsupported selector '.form-control::-moz-placeholder', Unknown pseudo-element: -moz-placeholder
# Invalid or unsupported selector '.form-control:-ms-input-placeholder', The pseudo-class :-ms-input-placeholder is unknown
# Invalid or unsupported selector '.form-control::-webkit-input-placeholder', Unknown pseudo-element: -webkit-input-placeholder
# Invalid or unsupported selector '.form-control::-ms-expand', Unknown pseudo-element: -ms-expand
# Ignored `cursor: not-allowed` at 5:37198, the property does not apply for the print media.
# Ignored `-webkit-appearance: none` at 5:37270, unknown property.
# Ignored `cursor: pointer` at 5:38256, the property does not apply for the print media.
# Ignored `margin-top: 4px\9` at 5:38415, invalid value.
# Ignored `cursor: pointer` at 5:38642, the property does not apply for the print media.
# Ignored `cursor: not-allowed` at 5:38942, the property does not apply for the print media.
# Ignored `cursor: not-allowed` at 5:39079, the property does not apply for the print media.
# Ignored `cursor: not-allowed` at 5:39212, the property does not apply for the print media.
# Ignored `pointer-events: none` at 5:40781, unknown property.
# Ignored `-webkit-box-shadow: inset 0 1px 1px rgba(0,0,0,.075)` at 5:41464, unknown property.
# Ignored `box-shadow: inset 0 1px 1px rgba(0,0,0,.075)` at 5:41516, unknown property.
# Ignored `-webkit-box-shadow: inset 0 1px 1px rgba(0,0,0,.075),0 0 6px #67b168` at 5:41614, unknown property.
# Ignored `box-shadow: inset 0 1px 1px rgba(0,0,0,.075),0 0 6px #67b168` at 5:41682, unknown property.
# Ignored `-webkit-box-shadow: inset 0 1px 1px rgba(0,0,0,.075)` at 5:42219, unknown property.
# Ignored `box-shadow: inset 0 1px 1px rgba(0,0,0,.075)` at 5:42271, unknown property.
# Ignored `-webkit-box-shadow: inset 0 1px 1px rgba(0,0,0,.075),0 0 6px #c0a16b` at 5:42369, unknown property.
# Ignored `box-shadow: inset 0 1px 1px rgba(0,0,0,.075),0 0 6px #c0a16b` at 5:42437, unknown property.
# Ignored `-webkit-box-shadow: inset 0 1px 1px rgba(0,0,0,.075)` at 5:42952, unknown property.
# Ignored `box-shadow: inset 0 1px 1px rgba(0,0,0,.075)` at 5:43004, unknown property.
# Ignored `-webkit-box-shadow: inset 0 1px 1px rgba(0,0,0,.075),0 0 6px #ce8483` at 5:43100, unknown property.
# Ignored `box-shadow: inset 0 1px 1px rgba(0,0,0,.075),0 0 6px #ce8483` at 5:43168, unknown property.
# Ignored `-ms-touch-action: manipulation` at 5:45322, unknown property.
# Ignored `touch-action: manipulation` at 5:45352, unknown property.
# Ignored `cursor: pointer` at 5:45378, the property does not apply for the print media.
# Ignored `-webkit-user-select: none` at 5:45393, unknown property.
# Ignored `-moz-user-select: none` at 5:45418, unknown property.
# Ignored `-ms-user-select: none` at 5:45440, unknown property.
# Ignored `user-select: none` at 5:45461, unknown property.
# Ignored `outline: 5px auto -webkit-focus-ring-color` at 5:45641, invalid value.
# Ignored `outline-offset: -2px` at 5:45683, unknown property.
# Ignored `-webkit-box-shadow: inset 0 3px 5px rgba(0,0,0,.125)` at 5:45824, unknown property.
# Ignored `box-shadow: inset 0 3px 5px rgba(0,0,0,.125)` at 5:45876, unknown property.
# Ignored `cursor: not-allowed` at 5:45973, the property does not apply for the print media.
# Ignored `filter: alpha(opacity=65)` at 5:45992, unknown property.
# Ignored `-webkit-box-shadow: none` at 5:46017, unknown property.
# Ignored `box-shadow: none` at 5:46041, unknown property.
# Ignored `pointer-events: none` at 5:46109, unknown property.
# Ignored `-webkit-box-shadow: none` at 5:53334, unknown property.
# Ignored `box-shadow: none` at 5:53358, unknown property.
# Ignored `-webkit-transition: opacity .15s linear` at 5:54184, unknown property.
# Ignored `-o-transition: opacity .15s linear` at 5:54223, unknown property.
# Ignored `transition: opacity .15s linear` at 5:54257, unknown property.
# Ignored `-webkit-transition-timing-function: ease` at 5:54487, unknown property.
# Ignored `-o-transition-timing-function: ease` at 5:54527, unknown property.
# Ignored `transition-timing-function: ease` at 5:54562, unknown property.
# Ignored `-webkit-transition-duration: .35s` at 5:54594, unknown property.
# Ignored `-o-transition-duration: .35s` at 5:54627, unknown property.
# Ignored `transition-duration: .35s` at 5:54655, unknown property.
# Ignored `-webkit-transition-property: height,visibility` at 5:54680, unknown property.
# Ignored `-o-transition-property: height,visibility` at 5:54726, unknown property.
# Ignored `transition-property: height,visibility` at 5:54767, unknown property.
# Ignored `border-top: 4px solid\9` at 5:54910, invalid value.
# Ignored `-webkit-background-clip: padding-box` at 5:55271, unknown property.
# Ignored `-webkit-box-shadow: 0 6px 12px rgba(0,0,0,.175)` at 5:55408, unknown property.
# Ignored `box-shadow: 0 6px 12px rgba(0,0,0,.175)` at 5:55455, unknown property.
# Ignored `cursor: not-allowed` at 5:56215, the property does not apply for the print media.
# Ignored `filter: progid:DXImageTransform.Microsoft.gradient(enabled=false)` at 5:56285, unknown property.
# Ignored `border-bottom: 4px solid\9` at 5:56819, invalid value.
# Ignored `-webkit-box-shadow: inset 0 3px 5px rgba(0,0,0,.125)` at 5:58855, unknown property.
# Ignored `box-shadow: inset 0 3px 5px rgba(0,0,0,.125)` at 5:58907, unknown property.
# Ignored `-webkit-box-shadow: none` at 5:58993, unknown property.
# Ignored `box-shadow: none` at 5:59017, unknown property.
# Ignored `pointer-events: none` at 5:60899, unknown property.
# Ignored `cursor: not-allowed` at 5:64819, the property does not apply for the print media.
# Ignored `cursor: default` at 5:65403, the property does not apply for the print media.
# Ignored `overflow-x: visible` at 5:67713, unknown property.
# Ignored `-webkit-overflow-scrolling: touch` at 5:67732, unknown property.
# Ignored `-webkit-box-shadow: inset 0 1px 0 rgba(255,255,255,.1)` at 5:67798, unknown property.
# Ignored `box-shadow: inset 0 1px 0 rgba(255,255,255,.1)` at 5:67852, unknown property.
# Ignored `overflow-y: auto` at 5:67918, unknown property.
# Ignored `-webkit-box-shadow: inset 0 1px 0 rgba(255,255,255,.1),0 1px 0 rgba(255,255,255,.1)` at 5:70896, unknown property.
# Ignored `box-shadow: inset 0 1px 0 rgba(255,255,255,.1),0 1px 0 rgba(255,255,255,.1)` at 5:70979, unknown property.
# Ignored `cursor: default` at 5:78924, the property does not apply for the print media.
# Ignored `cursor: not-allowed` at 5:79173, the property does not apply for the print media.
# Ignored `cursor: not-allowed` at 5:80418, the property does not apply for the print media.
# Ignored `cursor: pointer` at 5:80700, the property does not apply for the print media.
# Ignored `cursor: pointer` at 5:81882, the property does not apply for the print media.
# Ignored `-webkit-transition: border .2s ease-in-out` at 5:82862, unknown property.
# Ignored `-o-transition: border .2s ease-in-out` at 5:82904, unknown property.
# Ignored `transition: border .2s ease-in-out` at 5:82941, unknown property.
# Ignored `-webkit-box-shadow: inset 0 1px 2px rgba(0,0,0,.1)` at 5:84553, unknown property.
# Ignored `box-shadow: inset 0 1px 2px rgba(0,0,0,.1)` at 5:84603, unknown property.
# Ignored `-webkit-box-shadow: inset 0 -1px 0 rgba(0,0,0,.15)` at 5:84776, unknown property.
# Ignored `box-shadow: inset 0 -1px 0 rgba(0,0,0,.15)` at 5:84826, unknown property.
# Ignored `-webkit-transition: width .6s ease` at 5:84868, unknown property.
# Ignored `-o-transition: width .6s ease` at 5:84902, unknown property.
# Ignored `transition: width .6s ease` at 5:84931, unknown property.
# Ignored `background-image: -webkit-linear-gradient(45deg,rgba(255,255,255,.15) 25%,transparent 25%,transparent 50%,rgba(255,255,255,.15) 50%,rgba(255,255,255,.15) 75%,transparent 75%,transparent)` at 5:85011, invalid value.
# Ignored `background-image: -o-linear-gradient(45deg,rgba(255,255,255,.15) 25%,transparent 25%,transparent 50%,rgba(255,255,255,.15) 50%,rgba(255,255,255,.15) 75%,transparent 75%,transparent)` at 5:85197, invalid value.
# Ignored `-webkit-background-size: 40px 40px` at 5:85556, unknown property.
# Ignored `-webkit-animation: progress-bar-stripes 2s linear infinite` at 5:85668, unknown property.
# Ignored `-o-animation: progress-bar-stripes 2s linear infinite` at 5:85726, unknown property.
# Ignored `animation: progress-bar-stripes 2s linear infinite` at 5:85779, unknown property.
# Ignored `background-image: -webkit-linear-gradient(45deg,rgba(255,255,255,.15) 25%,transparent 25%,transparent 50%,rgba(255,255,255,.15) 50%,rgba(255,255,255,.15) 75%,transparent 75%,transparent)` at 5:85916, invalid value.
# Ignored `background-image: -o-linear-gradient(45deg,rgba(255,255,255,.15) 25%,transparent 25%,transparent 50%,rgba(255,255,255,.15) 50%,rgba(255,255,255,.15) 75%,transparent 75%,transparent)` at 5:86102, invalid value.
# Ignored `background-image: -webkit-linear-gradient(45deg,rgba(255,255,255,.15) 25%,transparent 25%,transparent 50%,rgba(255,255,255,.15) 50%,rgba(255,255,255,.15) 75%,transparent 75%,transparent)` at 5:86542, invalid value.
# Ignored `background-image: -o-linear-gradient(45deg,rgba(255,255,255,.15) 25%,transparent 25%,transparent 50%,rgba(255,255,255,.15) 50%,rgba(255,255,255,.15) 75%,transparent 75%,transparent)` at 5:86728, invalid value.
# Ignored `background-image: -webkit-linear-gradient(45deg,rgba(255,255,255,.15) 25%,transparent 25%,transparent 50%,rgba(255,255,255,.15) 50%,rgba(255,255,255,.15) 75%,transparent 75%,transparent)` at 5:87174, invalid value.
# Ignored `background-image: -o-linear-gradient(45deg,rgba(255,255,255,.15) 25%,transparent 25%,transparent 50%,rgba(255,255,255,.15) 50%,rgba(255,255,255,.15) 75%,transparent 75%,transparent)` at 5:87360, invalid value.
# Ignored `background-image: -webkit-linear-gradient(45deg,rgba(255,255,255,.15) 25%,transparent 25%,transparent 50%,rgba(255,255,255,.15) 50%,rgba(255,255,255,.15) 75%,transparent 75%,transparent)` at 5:87804, invalid value.
# Ignored `background-image: -o-linear-gradient(45deg,rgba(255,255,255,.15) 25%,transparent 25%,transparent 50%,rgba(255,255,255,.15) 50%,rgba(255,255,255,.15) 75%,transparent 75%,transparent)` at 5:87990, invalid value.
# Ignored `zoom: 1` at 5:88439, unknown property.
# Ignored `cursor: not-allowed` at 5:89711, the property does not apply for the print media.
# Ignored `-webkit-box-shadow: 0 1px 1px rgba(0,0,0,.05)` at 5:93996, unknown property.
# Ignored `box-shadow: 0 1px 1px rgba(0,0,0,.05)` at 5:94041, unknown property.
# Ignored `-webkit-box-shadow: inset 0 1px 1px rgba(0,0,0,.05)` at 5:105342, unknown property.
# Ignored `box-shadow: inset 0 1px 1px rgba(0,0,0,.05)` at 5:105393, unknown property.
# Ignored `text-shadow: 0 1px 0 #fff` at 5:105654, unknown property.
# Ignored `filter: alpha(opacity=20)` at 5:105679, unknown property.
# Ignored `cursor: pointer` at 5:105773, the property does not apply for the print media.
# Ignored `filter: alpha(opacity=50)` at 5:105788, unknown property.
# Ignored `-webkit-appearance: none` at 5:105837, unknown property.
# Ignored `cursor: pointer` at 5:105871, the property does not apply for the print media.
# Ignored `-webkit-overflow-scrolling: touch` at 5:106032, unknown property.
# Ignored `-webkit-transition: -webkit-transform .3s ease-out` at 5:106101, unknown property.
# Ignored `-o-transition: -o-transform .3s ease-out` at 5:106151, unknown property.
# Ignored `transition: transform .3s ease-out` at 5:106191, unknown property.
# Ignored `-webkit-transform: translate(0,-25%)` at 5:106225, unknown property.
# Ignored `-ms-transform: translate(0,-25%)` at 5:106261, unknown property.
# Ignored `-o-transform: translate(0,-25%)` at 5:106293, unknown property.
# Ignored `-webkit-transform: translate(0,0)` at 5:106376, unknown property.
# Ignored `-ms-transform: translate(0,0)` at 5:106409, unknown property.
# Ignored `-o-transform: translate(0,0)` at 5:106438, unknown property.
# Ignored `overflow-x: hidden` at 5:106510, unknown property.
# Ignored `overflow-y: auto` at 5:106528, unknown property.
# Ignored `-webkit-background-clip: padding-box` at 5:106654, unknown property.
# Ignored `-webkit-box-shadow: 0 3px 9px rgba(0,0,0,.5)` at 5:106800, unknown property.
# Ignored `box-shadow: 0 3px 9px rgba(0,0,0,.5)` at 5:106844, unknown property.
# Ignored `filter: alpha(opacity=0)` at 5:106997, unknown property.
# Ignored `filter: alpha(opacity=50)` at 5:107050, unknown property.
# Ignored `text-align: start` at 5:108029, invalid value.
# Ignored `text-shadow: none` at 5:108067, unknown property.
# Ignored `word-break: normal` at 5:108126, unknown property.
# Ignored `filter: alpha(opacity=0)` at 5:108200, unknown property.
# Ignored `line-break: auto` at 5:108234, unknown property.
# Ignored `filter: alpha(opacity=90)` at 5:108262, unknown property.
# Ignored `text-align: start` at 5:109830, invalid value.
# Ignored `text-shadow: none` at 5:109868, unknown property.
# Ignored `word-break: normal` at 5:109927, unknown property.
# Ignored `-webkit-background-clip: padding-box` at 5:110023, unknown property.
# Ignored `-webkit-box-shadow: 0 5px 10px rgba(0,0,0,.2)` at 5:110159, unknown property.
# Ignored `box-shadow: 0 5px 10px rgba(0,0,0,.2)` at 5:110204, unknown property.
# Ignored `line-break: auto` at 5:110241, unknown property.
# Ignored `-webkit-transition: .6s ease-in-out left` at 5:111898, unknown property.
# Ignored `-o-transition: .6s ease-in-out left` at 5:111938, unknown property.
# Ignored `transition: .6s ease-in-out left` at 5:111973, unknown property.
# Ignored `text-shadow: 0 1px 2px rgba(0,0,0,.6)` at 5:113351, unknown property.
# Ignored `filter: alpha(opacity=50)` at 5:113419, unknown property.
# Ignored `background-image: -webkit-linear-gradient(left,rgba(0,0,0,.5) 0,rgba(0,0,0,.0001) 100%)` at 5:113478, invalid value.
# Ignored `background-image: -o-linear-gradient(left,rgba(0,0,0,.5) 0,rgba(0,0,0,.0001) 100%)` at 5:113565, invalid value.
# Ignored `background-image: -webkit-gradient(linear,left top,right top,from(rgba(0,0,0,.5)),to(rgba(0,0,0,.0001)))` at 5:113647, invalid value.
# Ignored `filter: progid:DXImageTransform.Microsoft.gradient(startColorstr='#80000000', endColorstr='#00000000', GradientType=1)` at 5:113834, unknown property.
# Ignored `background-image: -webkit-linear-gradient(left,rgba(0,0,0,.0001) 0,rgba(0,0,0,.5) 100%)` at 5:114021, invalid value.
# Ignored `background-image: -o-linear-gradient(left,rgba(0,0,0,.0001) 0,rgba(0,0,0,.5) 100%)` at 5:114108, invalid value.
# Ignored `background-image: -webkit-gradient(linear,left top,right top,from(rgba(0,0,0,.0001)),to(rgba(0,0,0,.5)))` at 5:114190, invalid value.
# Ignored `filter: progid:DXImageTransform.Microsoft.gradient(startColorstr='#00000000', endColorstr='#80000000', GradientType=1)` at 5:114377, unknown property.
# Ignored `filter: alpha(opacity=90)` at 5:114602, unknown property.
# Ignored `cursor: pointer` at 5:115526, the property does not apply for the print media.
# Ignored `background-color: #000\9` at 5:115541, invalid value.
# Ignored `text-shadow: 0 1px 2px rgba(0,0,0,.6)` at 5:115864, unknown property.
# Ignored `text-shadow: none` at 5:115924, unknown property.
# Ignored `text-shadow: none` at 5:117722, unknown property.
# Parse error at 5:3012, unknown at-rule in stylesheet context: @font-face
# Parse error at 5:17590, expected a media type, got (
# Parse error at 5:19357, expected a media type, got (
# Parse error at 5:21602, expected a media type, got (
# Parse error at 5:21651, expected a media type, got (
# Parse error at 5:21700, expected a media type, got (
# Parse error at 5:24184, expected a media type, got (
# Parse error at 5:25950, expected a media type, got (
# Parse error at 5:27716, expected a media type, got (
# Parse error at 5:33835, expected a media type, got IDENT, IDENT, (
# Parse error at 5:37301, expected a media type, got IDENT, IDENT, (
# Parse error at 5:43556, expected a media type, got (
# Parse error at 5:44776, expected a media type, got (
# Parse error at 5:44948, expected a media type, got (
# Parse error at 5:45053, expected a media type, got (
# Parse error at 5:56960, expected a media type, got (
# Parse error at 5:65723, expected a media type, got (
# Parse error at 5:66047, expected a media type, got (
# Parse error at 5:66750, expected a media type, got (
# Parse error at 5:67076, expected a media type, got (
# Parse error at 5:67562, expected a media type, got (
# Parse error at 5:67614, expected a media type, got (
# Parse error at 5:67941, expected a media type, got (
# Parse error at 5:68433, expected a media type, got (, IDENT, (
# Parse error at 5:68741, expected a media type, got (
# Parse error at 5:68969, expected a media type, got (
# Parse error at 5:69112, expected a media type, got (
# Parse error at 5:69485, expected a media type, got (
# Parse error at 5:69972, expected a media type, got (
# Parse error at 5:70128, expected a media type, got (
# Parse error at 5:70595, expected a media type, got (
# Parse error at 5:71061, expected a media type, got (
# Parse error at 5:71987, expected a media type, got (
# Parse error at 5:72108, expected a media type, got (
# Parse error at 5:72741, expected a media type, got (
# Parse error at 5:72826, expected a media type, got (
# Parse error at 5:74185, expected a media type, got (
# Parse error at 5:76495, expected a media type, got (
# Parse error at 5:82512, expected a media type, got IDENT, IDENT, (
# Parse error at 5:84166, unknown at-rule in stylesheet context: @-webkit-keyframes
# Parse error at 5:84266, unknown at-rule in stylesheet context: @-o-keyframes
# Parse error at 5:84361, unknown at-rule in stylesheet context: @keyframes
# Parse error at 5:107602, expected a media type, got (
# Parse error at 5:107790, expected a media type, got (
# Parse error at 5:112080, expected a media type, got IDENT, IDENT, (
# Parse error at 5:115948, expected a media type, got IDENT, IDENT, (
# Parse error at 5:117830, unknown at-rule in stylesheet context: @-ms-viewport
# Parse error at 5:118212, expected a media type, got (
# Parse error at 5:118414, expected a media type, got (
# Parse error at 5:118482, expected a media type, got (
# Parse error at 5:118552, expected a media type, got (
# Parse error at 5:118634, expected a media type, got (, IDENT, (
# Parse error at 5:118858, expected a media type, got (, IDENT, (
# Parse error at 5:118948, expected a media type, got (, IDENT, (
# Parse error at 5:119040, expected a media type, got (, IDENT, (
# Parse error at 5:119144, expected a media type, got (, IDENT, (
# Parse error at 5:119369, expected a media type, got (, IDENT, (
# Parse error at 5:119460, expected a media type, got (, IDENT, (
# Parse error at 5:119553, expected a media type, got (, IDENT, (
# Parse error at 5:119658, expected a media type, got (
# Parse error at 5:119861, expected a media type, got (
# Parse error at 5:119930, expected a media type, got (
# Parse error at 5:120001, expected a media type, got (
# Parse error at 5:120084, expected a media type, got (
# Parse error at 5:120144, expected a media type, got (, IDENT, (
# Parse error at 5:120226, expected a media type, got (, IDENT, (
# Parse error at 5:120309, expected a media type, got (
# Ignored `text-shadow: 0 -1px 0 rgba(0,0,0,.2)` at 5:78, unknown property.
# Ignored `-webkit-box-shadow: inset 0 1px 0 rgba(255,255,255,.15),0 1px 1px rgba(0,0,0,.075)` at 5:114, unknown property.
# Ignored `box-shadow: inset 0 1px 0 rgba(255,255,255,.15),0 1px 1px rgba(0,0,0,.075)` at 5:196, unknown property.
# Ignored `-webkit-box-shadow: inset 0 3px 5px rgba(0,0,0,.125)` at 5:502, unknown property.
# Ignored `box-shadow: inset 0 3px 5px rgba(0,0,0,.125)` at 5:554, unknown property.
# Ignored `-webkit-box-shadow: none` at 5:1048, unknown property.
# Ignored `box-shadow: none` at 5:1072, unknown property.
# Ignored `text-shadow: none` at 5:1204, unknown property.
# Ignored `text-shadow: 0 1px 0 #fff` at 5:1280, unknown property.
# Ignored `background-image: -webkit-linear-gradient(top,#fff 0,#e0e0e0 100%)` at 5:1305, invalid value.
# Ignored `background-image: -o-linear-gradient(top,#fff 0,#e0e0e0 100%)` at 5:1371, invalid value.
# Ignored `background-image: -webkit-gradient(linear,left top,left bottom,from(#fff),to(#e0e0e0))` at 5:1432, invalid value.
# Ignored `filter: progid:DXImageTransform.Microsoft.gradient(startColorstr='#ffffffff', endColorstr='#ffe0e0e0', GradientType=0)` at 5:1582, unknown property.
# Ignored `filter: progid:DXImageTransform.Microsoft.gradient(enabled=false)` at 5:1700, unknown property.
# Ignored `background-image: -webkit-linear-gradient(top,#337ab7 0,#265a88 100%)` at 5:2626, invalid value.
# Ignored `background-image: -o-linear-gradient(top,#337ab7 0,#265a88 100%)` at 5:2695, invalid value.
# Ignored `background-image: -webkit-gradient(linear,left top,left bottom,from(#337ab7),to(#265a88))` at 5:2759, invalid value.
# Ignored `filter: progid:DXImageTransform.Microsoft.gradient(startColorstr='#ff337ab7', endColorstr='#ff265a88', GradientType=0)` at 5:2915, unknown property.
# Ignored `filter: progid:DXImageTransform.Microsoft.gradient(enabled=false)` at 5:3033, unknown property.
# Ignored `background-image: -webkit-linear-gradient(top,#5cb85c 0,#419641 100%)` at 5:3941, invalid value.
# Ignored `background-image: -o-linear-gradient(top,#5cb85c 0,#419641 100%)` at 5:4010, invalid value.
# Ignored `background-image: -webkit-gradient(linear,left top,left bottom,from(#5cb85c),to(#419641))` at 5:4074, invalid value.
# Ignored `filter: progid:DXImageTransform.Microsoft.gradient(startColorstr='#ff5cb85c', endColorstr='#ff419641', GradientType=0)` at 5:4230, unknown property.
