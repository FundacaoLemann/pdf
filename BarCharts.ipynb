# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./20161002.holandakhan.active_users.bar_chart.csv', delimiter='|', index_col=[0], header=0)

# %%
df
# Out:
#                 perc_alunos_ativos
# escolas
# ALENCAR                         39
# ALICE                           18
# ALIPIO                          16
# ANEZIO                          18
# AYRES                           21
# BAPTISTA                        36
# BIONDO                           1
# BITTENCOURT                     25
# BORTOLOSSO                      32
# BRECHERET                       57
# CAMPESTRINI                     41
# CASTELANI                       61
# DARCY                            0
# DOMINGOS                        17
# ELIDIO                          16
# ELIO                            68
# ELZA                            54
# ETIENE                          41
# FARHAT                           7
# FERRAZ                           9
# FIUZA                           40
# GASPARZINHO                     13
# GROSSI                          22
# GUIMARAES                       50
# HAIDAR                          58
# ...

# %% [markdown]
# # Generate the plot

# %%
params = {
    'kind': 'bar',
    'ylim': (0, 100),
    'legend': False,
    'figsize': (14, 7),
    'grid': True,
    'color': "#339966",
    'rot': 90
}

# %%
# generate the plot
plot = df.plot(**params)

# annotate the values above the bars
for idx, label in enumerate(list(df.index)): 
    for acc in df.columns:
        value = np.round(df.ix[idx][acc],decimals=2)
        plot.annotate(value, (idx, value), xytext=(0, 15), textcoords='offset points')

# set the labels
plot.set_ylabel('% USUARIOS')
plot.set_xlabel('Escolas')

# export chart
fig = plot.get_figure()
fig.tight_layout()
fig.savefig("output.png")

# %%
from weasyprint import HTML
HTML('ab.html').write_pdf('./weekly_report.pdf')
# Out:
# OSErrorTraceback (most recent call last)
# <ipython-input-7-ab3b7be2ece3> in <module>()
# ----> 1 from weasyprint import HTML
#       2 HTML('ab.html').write_pdf('./weekly_report.pdf')
#
# C:\Anaconda2\lib\site-packages\weasyprint\__init__.py in <module>()
#     336
#     337 # Work around circular imports.
# --> 338 from .css import PARSER, preprocess_stylesheet  # noqa
#     339 from .html import find_base_url, HTML5_UA_STYLESHEET, get_html_metadata  # noqa
#     340 from .document import Document, Page  # noqa
#
# C:\Anaconda2\lib\site-packages\weasyprint\css\__init__.py in <module>()
#      28
#      29 from . import properties
# ---> 30 from . import computed_values
#      31 from .validation import preprocess_declarations
#      32 from ..urls import (element_base_url, get_url_attribute, url_join,
#
# C:\Anaconda2\lib\site-packages\weasyprint\css\computed_values.py in <module>()
#      16 from .properties import INITIAL_VALUES, Dimension
# ...
